# %%
import fastf1
fastf1.Cache.enable_cache('../data')  # points to the shared data folder

# %%
session = fastf1.get_session(2023, 'Qatar Grand Prix', 'R')  # R = race
session.load()
# Out:
# events      WARNING 	Correcting user input 'Qatar Grand Prix' to 'Qatar Grand Prix'
# core           INFO 	Loading data for Qatar Grand Prix - Race [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for lap_count. Loading data...
# _api           INFO 	Fetching lap count data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for _extended_timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate (driver 55)
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 241: Position data is incomplete!
# _api        WARNING 	Driver 242: Position data is incomplete!
# _api        WARNING 	Driver 243: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '81', '4', '63', '16', '14', '31', '77', '24', '11', '18', '10', '23', '20', '22', '27', '40', '2', '44', '55']

# %%
results = session.results
results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 81           81     O PIASTRI          PIA          piastri          McLaren
# 4             4      L NORRIS          NOR           norris          McLaren
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 31           31        E OCON          OCO             ocon           Alpine
# 77           77      V BOTTAS          BOT           bottas       Alfa Romeo
# 24           24        G ZHOU          ZHO             zhou       Alfa Romeo
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 18           18      L STROLL          STR           stroll     Aston Martin
# 10           10       P GASLY          GAS            gasly           Alpine
# 23           23       A ALBON          ALB            albon         Williams
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen     Haas F1 Team
# 22           22     Y TSUNODA          TSU          tsunoda       AlphaTauri
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 40           40      L LAWSON          LAW           lawson       AlphaTauri
# 2             2    L SARGEANT          SAR         sargeant         Williams
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 55           55       C SAINZ          SAI            sainz          Ferrari
#
#    TeamColor        TeamId  FirstName    LastName         FullName  ...  \
# 1     3671C6      red_bull        Max  Verstappen   Max Verstappen  ...
# 81    F58020       mclaren      Oscar     Piastri    Oscar Piastri  ...
# 4     F58020       mclaren      Lando      Norris     Lando Norris  ...
# 63    6CD3BF      mercedes     George     Russell   George Russell  ...
# 16    F91536       ferrari    Charles     Leclerc  Charles Leclerc  ...
# 14    358C75  aston_martin   Fernando      Alonso  Fernando Alonso  ...
# 31    2293D1        alpine    Esteban        Ocon     Esteban Ocon  ...
# 77    C92D4B          alfa   Valtteri      Bottas  Valtteri Bottas  ...
# 24    C92D4B          alfa     Guanyu        Zhou      Guanyu Zhou  ...
# 11    3671C6      red_bull     Sergio       Perez     Sergio Perez  ...
# 18    358C75  aston_martin      Lance      Stroll     Lance Stroll  ...
# 10    2293D1        alpine     Pierre       Gasly     Pierre Gasly  ...
# 23    37BEDD      williams  Alexander       Albon  Alexander Albon  ...
# 20    B6BABD          haas      Kevin   Magnussen  Kevin Magnussen  ...
# 22    5E8FAA    alphatauri       Yuki     Tsunoda     Yuki Tsunoda  ...
# 27    B6BABD          haas       Nico  Hulkenberg  Nico Hulkenberg  ...
# 40    5E8FAA    alphatauri       Liam      Lawson      Liam Lawson  ...
# 2     37BEDD      williams      Logan    Sargeant   Logan Sargeant  ...
# 44    6CD3BF      mercedes      Lewis    Hamilton   Lewis Hamilton  ...
# 55    F91536       ferrari     Carlos       Sainz     Carlos Sainz  ...
#
#    Position ClassifiedPosition  GridPosition  Q1  Q2  Q3  \
# 1       1.0                  1           1.0 NaT NaT NaT
# 81      2.0                  2           6.0 NaT NaT NaT
# 4       3.0                  3          10.0 NaT NaT NaT
# 63      4.0                  4           2.0 NaT NaT NaT
# 16      5.0                  5           5.0 NaT NaT NaT
# 14      6.0                  6           4.0 NaT NaT NaT
# 31      7.0                  7           8.0 NaT NaT NaT
# 77      8.0                  8           9.0 NaT NaT NaT
# 24      9.0                  9          19.0 NaT NaT NaT
# 11     10.0                 10          20.0 NaT NaT NaT
# 18     11.0                 11          16.0 NaT NaT NaT
# 10     12.0                 12           7.0 NaT NaT NaT
# 23     13.0                 13          13.0 NaT NaT NaT
# 20     14.0                 14          18.0 NaT NaT NaT
# 22     15.0                 15          11.0 NaT NaT NaT
# 27     16.0                 16          14.0 NaT NaT NaT
# 40     17.0                 17          17.0 NaT NaT NaT
# 2      18.0                  R          15.0 NaT NaT NaT
# 44     19.0                  R           3.0 NaT NaT NaT
# 55     20.0                  W          12.0 NaT NaT NaT
#
#                      Time         Status Points  Laps
# 1  0 days 01:27:39.168000       Finished   26.0  57.0
# 81 0 days 00:00:04.833000       Finished   18.0  57.0
# 4  0 days 00:00:05.969000       Finished   15.0  57.0
# 63 0 days 00:00:34.119000       Finished   12.0  57.0
# 16 0 days 00:00:38.976000       Finished   10.0  57.0
# 14 0 days 00:00:49.032000       Finished    8.0  57.0
# 31 0 days 00:01:02.390000       Finished    6.0  57.0
# 77 0 days 00:01:06.563000       Finished    4.0  57.0
# 24 0 days 00:01:16.127000       Finished    2.0  57.0
# 11 0 days 00:01:20.181000       Finished    1.0  57.0
# 18 0 days 00:01:21.652000       Finished    0.0  57.0
# 10 0 days 00:01:22.300000       Finished    0.0  57.0
# 23 0 days 00:01:31.014000       Finished    0.0  57.0
# 20 0 days 00:00:01.246000         Lapped    0.0  56.0
# 22 0 days 00:00:08.958000         Lapped    0.0  56.0
# 27 0 days 00:00:15.085000         Lapped    0.0  56.0
# 40 0 days 00:00:27.108000         Lapped    0.0  56.0
# 2                     NaT        Retired    0.0  40.0
# 44                    NaT        Retired    0.0   0.0
# 55                    NaT  Did not start    0.0   0.0
#
# [20 rows x 22 columns]

# %%
# lap data
laps = session.laps
laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 0    0 days 01:04:22.816000    VER            1 0 days 00:01:48.811000
# 1    0 days 01:06:48.419000    VER            1 0 days 00:02:25.603000
# 2    0 days 01:09:14.382000    VER            1 0 days 00:02:25.963000
# 3    0 days 01:11:47.524000    VER            1                    NaT
# 4    0 days 01:13:17.797000    VER            1 0 days 00:01:30.273000
# ...                     ...    ...          ...                    ...
# 1001 0 days 02:02:11.987000    SAR            2 0 days 00:01:28.881000
# 1002 0 days 02:03:40.963000    SAR            2 0 days 00:01:28.976000
# 1003 0 days 02:05:10.550000    SAR            2 0 days 00:01:29.587000
# 1004 0 days 02:07:02.211000    SAR            2 0 days 00:01:51.661000
# 1005 0 days 01:04:22.816000    HAM           44                    NaT
#
#       LapNumber  Stint PitOutTime              PitInTime  \
# 0           1.0    1.0        NaT                    NaT
# 1           2.0    1.0        NaT                    NaT
# 2           3.0    1.0        NaT                    NaT
# 3           4.0    1.0        NaT                    NaT
# 4           5.0    1.0        NaT                    NaT
# ...         ...    ...        ...                    ...
# 1001       37.0    3.0        NaT                    NaT
# 1002       38.0    3.0        NaT                    NaT
# 1003       39.0    3.0        NaT                    NaT
# 1004       40.0    3.0        NaT 0 days 02:06:58.134000
# 1005        1.0    1.0        NaT                    NaT
#
#                 Sector1Time            Sector2Time  ... FreshTyre  \
# 0                       NaT 0 days 00:00:30.570000  ...     False
# 1    0 days 00:00:56.965000 0 days 00:00:45.684000  ...     False
# 2    0 days 00:00:56.379000 0 days 00:00:46.050000  ...     False
# 3    0 days 00:00:50.072000 0 days 00:00:46.453000  ...     False
# 4    0 days 00:00:33.310000 0 days 00:00:30.260000  ...     False
# ...                     ...                    ...  ...       ...
# 1001 0 days 00:00:32.614000 0 days 00:00:30.202000  ...      True
# 1002 0 days 00:00:32.626000 0 days 00:00:30.234000  ...      True
# 1003 0 days 00:00:32.604000 0 days 00:00:30.890000  ...      True
# 1004 0 days 00:00:33.166000 0 days 00:00:31.513000  ...      True
# 1005                    NaT                    NaT  ...      True
#
#                  Team           LapStartTime            LapStartDate  \
# 0     Red Bull Racing 0 days 01:02:33.771000 2023-10-08 17:03:33.776
# 1     Red Bull Racing 0 days 01:04:22.816000 2023-10-08 17:05:22.821
# 2     Red Bull Racing 0 days 01:06:48.419000 2023-10-08 17:07:48.424
# 3     Red Bull Racing 0 days 01:09:14.382000 2023-10-08 17:10:14.387
# 4     Red Bull Racing 0 days 01:11:47.524000 2023-10-08 17:12:47.529
# ...               ...                    ...                     ...
# 1001         Williams 0 days 02:00:43.106000 2023-10-08 18:01:43.111
# 1002         Williams 0 days 02:02:11.987000 2023-10-08 18:03:11.992
# 1003         Williams 0 days 02:03:40.963000 2023-10-08 18:04:40.968
# 1004         Williams 0 days 02:05:10.550000 2023-10-08 18:06:10.555
# 1005         Mercedes 0 days 01:02:33.771000 2023-10-08 17:03:33.776
#
#       TrackStatus  Position  Deleted                   DeletedReason  \
# 0             124       1.0    False
# 1               4       1.0    False
# 2               4       1.0    False
# 3              41       1.0    False
# 4               1       1.0    False
# ...           ...       ...      ...                             ...
# 1001            1      18.0    False
# 1002            1      18.0     True  TRACK LIMITS AT TURN 2 LAP 38
# 1003            1      17.0    False
# 1004           12      17.0    False
# 1005          124       NaN    False
#
#       FastF1Generated IsAccurate
# 0               False      False
# 1               False      False
# 2               False      False
# 3               False      False
# 4               False       True
# ...               ...        ...
# 1001            False       True
# 1002            False       True
# 1003            False       True
# 1004            False      False
# 1005             True      False
#
# [1006 rows x 31 columns]

# %%
# clean data
laps = laps[laps['TrackStatus'] == '1'] # 1 == green flag
laps = laps[laps['PitInTime'].isna() & laps['PitOutTime'].isna()] # pit-in and pit-out laps are slow
laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 4    0 days 01:13:17.797000    VER            1 0 days 00:01:30.273000
# 5    0 days 01:14:47.206000    VER            1 0 days 00:01:29.409000
# 6    0 days 01:16:16.289000    VER            1 0 days 00:01:29.083000
# 7    0 days 01:17:45.651000    VER            1 0 days 00:01:29.362000
# 8    0 days 01:19:14.977000    VER            1 0 days 00:01:29.326000
# ...                     ...    ...          ...                    ...
# 999  0 days 01:59:14.052000    SAR            2 0 days 00:01:28.571000
# 1000 0 days 02:00:43.106000    SAR            2 0 days 00:01:29.054000
# 1001 0 days 02:02:11.987000    SAR            2 0 days 00:01:28.881000
# 1002 0 days 02:03:40.963000    SAR            2 0 days 00:01:28.976000
# 1003 0 days 02:05:10.550000    SAR            2 0 days 00:01:29.587000
#
#       LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 4           5.0    1.0        NaT       NaT 0 days 00:00:33.310000
# 5           6.0    1.0        NaT       NaT 0 days 00:00:33.139000
# 6           7.0    1.0        NaT       NaT 0 days 00:00:32.850000
# 7           8.0    1.0        NaT       NaT 0 days 00:00:33.037000
# 8           9.0    1.0        NaT       NaT 0 days 00:00:33.034000
# ...         ...    ...        ...       ...                    ...
# 999        35.0    3.0        NaT       NaT 0 days 00:00:32.608000
# 1000       36.0    3.0        NaT       NaT 0 days 00:00:32.772000
# 1001       37.0    3.0        NaT       NaT 0 days 00:00:32.614000
# 1002       38.0    3.0        NaT       NaT 0 days 00:00:32.626000
# 1003       39.0    3.0        NaT       NaT 0 days 00:00:32.604000
#
#                 Sector2Time  ... FreshTyre             Team  \
# 4    0 days 00:00:30.260000  ...     False  Red Bull Racing
# 5    0 days 00:00:29.969000  ...     False  Red Bull Racing
# 6    0 days 00:00:29.847000  ...     False  Red Bull Racing
# 7    0 days 00:00:29.899000  ...     False  Red Bull Racing
# 8    0 days 00:00:29.860000  ...     False  Red Bull Racing
# ...                     ...  ...       ...              ...
# 999  0 days 00:00:29.978000  ...      True         Williams
# 1000 0 days 00:00:30.294000  ...      True         Williams
# 1001 0 days 00:00:30.202000  ...      True         Williams
# 1002 0 days 00:00:30.234000  ...      True         Williams
# 1003 0 days 00:00:30.890000  ...      True         Williams
#
#                LapStartTime            LapStartDate  TrackStatus  Position  \
# 4    0 days 01:11:47.524000 2023-10-08 17:12:47.529            1       1.0
# 5    0 days 01:13:17.797000 2023-10-08 17:14:17.802            1       1.0
# 6    0 days 01:14:47.206000 2023-10-08 17:15:47.211            1       1.0
# 7    0 days 01:16:16.289000 2023-10-08 17:17:16.294            1       1.0
# 8    0 days 01:17:45.651000 2023-10-08 17:18:45.656            1       1.0
# ...                     ...                     ...          ...       ...
# 999  0 days 01:57:45.481000 2023-10-08 17:58:45.486            1      18.0
# 1000 0 days 01:59:14.052000 2023-10-08 18:00:14.057            1      18.0
# 1001 0 days 02:00:43.106000 2023-10-08 18:01:43.111            1      18.0
# 1002 0 days 02:02:11.987000 2023-10-08 18:03:11.992            1      18.0
# 1003 0 days 02:03:40.963000 2023-10-08 18:04:40.968            1      17.0
#
#       Deleted                   DeletedReason  FastF1Generated IsAccurate
# 4       False                                            False       True
# 5       False                                            False       True
# 6       False                                            False       True
# 7       False                                            False       True
# 8       False                                            False       True
# ...       ...                             ...              ...        ...
# 999     False                                            False       True
# 1000    False                                            False       True
# 1001    False                                            False       True
# 1002     True  TRACK LIMITS AT TURN 2 LAP 38             False       True
# 1003    False                                            False       True
#
# [806 rows x 31 columns]

# %%
# laptime from TimeDelta type to seconds
laps['LapTime(seconds)'] = laps['LapTime'].dt.total_seconds()
laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 4    0 days 01:13:17.797000    VER            1 0 days 00:01:30.273000
# 5    0 days 01:14:47.206000    VER            1 0 days 00:01:29.409000
# 6    0 days 01:16:16.289000    VER            1 0 days 00:01:29.083000
# 7    0 days 01:17:45.651000    VER            1 0 days 00:01:29.362000
# 8    0 days 01:19:14.977000    VER            1 0 days 00:01:29.326000
# ...                     ...    ...          ...                    ...
# 999  0 days 01:59:14.052000    SAR            2 0 days 00:01:28.571000
# 1000 0 days 02:00:43.106000    SAR            2 0 days 00:01:29.054000
# 1001 0 days 02:02:11.987000    SAR            2 0 days 00:01:28.881000
# 1002 0 days 02:03:40.963000    SAR            2 0 days 00:01:28.976000
# 1003 0 days 02:05:10.550000    SAR            2 0 days 00:01:29.587000
#
#       LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 4           5.0    1.0        NaT       NaT 0 days 00:00:33.310000
# 5           6.0    1.0        NaT       NaT 0 days 00:00:33.139000
# 6           7.0    1.0        NaT       NaT 0 days 00:00:32.850000
# 7           8.0    1.0        NaT       NaT 0 days 00:00:33.037000
# 8           9.0    1.0        NaT       NaT 0 days 00:00:33.034000
# ...         ...    ...        ...       ...                    ...
# 999        35.0    3.0        NaT       NaT 0 days 00:00:32.608000
# 1000       36.0    3.0        NaT       NaT 0 days 00:00:32.772000
# 1001       37.0    3.0        NaT       NaT 0 days 00:00:32.614000
# 1002       38.0    3.0        NaT       NaT 0 days 00:00:32.626000
# 1003       39.0    3.0        NaT       NaT 0 days 00:00:32.604000
#
#                 Sector2Time  ...             Team           LapStartTime  \
# 4    0 days 00:00:30.260000  ...  Red Bull Racing 0 days 01:11:47.524000
# 5    0 days 00:00:29.969000  ...  Red Bull Racing 0 days 01:13:17.797000
# 6    0 days 00:00:29.847000  ...  Red Bull Racing 0 days 01:14:47.206000
# 7    0 days 00:00:29.899000  ...  Red Bull Racing 0 days 01:16:16.289000
# 8    0 days 00:00:29.860000  ...  Red Bull Racing 0 days 01:17:45.651000
# ...                     ...  ...              ...                    ...
# 999  0 days 00:00:29.978000  ...         Williams 0 days 01:57:45.481000
# 1000 0 days 00:00:30.294000  ...         Williams 0 days 01:59:14.052000
# 1001 0 days 00:00:30.202000  ...         Williams 0 days 02:00:43.106000
# 1002 0 days 00:00:30.234000  ...         Williams 0 days 02:02:11.987000
# 1003 0 days 00:00:30.890000  ...         Williams 0 days 02:03:40.963000
#
#                 LapStartDate TrackStatus  Position  Deleted  \
# 4    2023-10-08 17:12:47.529           1       1.0    False
# 5    2023-10-08 17:14:17.802           1       1.0    False
# 6    2023-10-08 17:15:47.211           1       1.0    False
# 7    2023-10-08 17:17:16.294           1       1.0    False
# 8    2023-10-08 17:18:45.656           1       1.0    False
# ...                      ...         ...       ...      ...
# 999  2023-10-08 17:58:45.486           1      18.0    False
# 1000 2023-10-08 18:00:14.057           1      18.0    False
# 1001 2023-10-08 18:01:43.111           1      18.0    False
# 1002 2023-10-08 18:03:11.992           1      18.0     True
# 1003 2023-10-08 18:04:40.968           1      17.0    False
#
#                        DeletedReason  FastF1Generated  IsAccurate  \
# 4                                               False        True
# 5                                               False        True
# 6                                               False        True
# 7                                               False        True
# 8                                               False        True
# ...                              ...              ...         ...
# 999                                             False        True
# 1000                                            False        True
# 1001                                            False        True
# 1002  TRACK LIMITS AT TURN 2 LAP 38             False        True
# 1003                                            False        True
#
#      LapTime(seconds)
# 4              90.273
# 5              89.409
# 6              89.083
# 7              89.362
# 8              89.326
# ...               ...
# 999            88.571
# 1000           89.054
# 1001           88.881
# 1002           88.976
# 1003           89.587
#
# [806 rows x 32 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 8))
sns.boxplot(
    data = laps,
    x = 'Driver',
    y = 'LapTime(seconds)'
)
plt.title('Lap Time Distribution by Driver')
plt.show()

# %% [markdown]
# Box position shows the pace, box height shows the consistency.

# %%
# consistency -> lower std, more consistent
consistency = laps.groupby('Driver')['LapTime(seconds)'].agg(['mean', 'std']).reset_index()
consistency.columns = ['Driver', 'AvgLapTime', 'Consistency(std)']
consistency
# Out:
#    Driver  AvgLapTime  Consistency(std)
# 0     ALB   88.636174          1.639131
# 1     ALO   87.930933          1.410480
# 2     BOT   88.841687          1.861188
# 3     GAS   88.381533          1.539145
# 4     HUL   88.753867          1.475983
# 5     LAW   89.837915          1.702045
# 6     LEC   87.927556          1.681092
# 7     MAG   89.379783          1.934190
# 8     NOR   87.350311          2.036646
# 9     OCO   88.314978          1.381854
# 10    PER   88.466222          1.783894
# 11    PIA   87.245867          1.704436
# 12    RUS   87.897326          1.932226
# 13    SAR   89.781767          1.270905
# 14    STR   88.969771          1.892567
# 15    TSU   89.025689          1.400266
# 16    VER   87.282333          1.553770
# 17    ZHO   88.662800          1.867324

# %%
laps.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'LapTime(seconds)'],
#       dtype='object')

# %%
consistency = consistency.sort_values('Consistency(std)')
plt.figure(figsize = (10, 8))
sns.barplot(
    data = consistency,
    x = 'Consistency(std)',
    y = 'Driver'
)
plt.title('Driver Consistency')
plt.show()

# %% [markdown]
# Lower std = more consistent driver.

# %%
results.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
#        'HeadshotUrl', 'CountryCode', 'Position', 'ClassifiedPosition',
#        'GridPosition', 'Q1', 'Q2', 'Q3', 'Time', 'Status', 'Points', 'Laps'],
#       dtype='object')

# %%
top_5_drivers = results.sort_values('Position').head()['Abbreviation']
top_5_drivers
# Out:
# 1     VER
# 81    PIA
# 4     NOR
# 63    RUS
# 16    LEC
# Name: Abbreviation, dtype: object

# %%
top_5_lap = laps[laps['Driver'].isin(top_5_drivers)][['Driver', 'LapNumber', 'LapTime(seconds)']]
top_5_lap
# Out:
#     Driver  LapNumber  LapTime(seconds)
# 4      VER        5.0            90.273
# 5      VER        6.0            89.409
# 6      VER        7.0            89.083
# 7      VER        8.0            89.362
# 8      VER        9.0            89.326
# ..     ...        ...               ...
# 280    LEC       53.0            86.668
# 281    LEC       54.0            86.721
# 282    LEC       55.0            85.813
# 283    LEC       56.0            88.088
# 284    LEC       57.0            84.992
#
# [226 rows x 3 columns]

# %%
plt.figure(figsize = (12, 6))
sns.lineplot(
    data = top_5_lap,
    x = 'LapTime(seconds)',
    y = 'LapNumber',
    hue = 'Driver'
)
plt.title('Lap Time Evolution Throughout the Race')
plt.show()

# %%
# comparing sector times
laps['Sector1Time(seconds)'] = laps['Sector1Time'].dt.total_seconds()
laps['Sector2Time(seconds)'] = laps['Sector2Time'].dt.total_seconds()
laps['Sector3Time(seconds)'] = laps['Sector3Time'].dt.total_seconds()
laps
# Out:
#                        Time Driver DriverNumber                LapTime  \
# 4    0 days 01:13:17.797000    VER            1 0 days 00:01:30.273000
# 5    0 days 01:14:47.206000    VER            1 0 days 00:01:29.409000
# 6    0 days 01:16:16.289000    VER            1 0 days 00:01:29.083000
# 7    0 days 01:17:45.651000    VER            1 0 days 00:01:29.362000
# 8    0 days 01:19:14.977000    VER            1 0 days 00:01:29.326000
# ...                     ...    ...          ...                    ...
# 999  0 days 01:59:14.052000    SAR            2 0 days 00:01:28.571000
# 1000 0 days 02:00:43.106000    SAR            2 0 days 00:01:29.054000
# 1001 0 days 02:02:11.987000    SAR            2 0 days 00:01:28.881000
# 1002 0 days 02:03:40.963000    SAR            2 0 days 00:01:28.976000
# 1003 0 days 02:05:10.550000    SAR            2 0 days 00:01:29.587000
#
#       LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 4           5.0    1.0        NaT       NaT 0 days 00:00:33.310000
# 5           6.0    1.0        NaT       NaT 0 days 00:00:33.139000
# 6           7.0    1.0        NaT       NaT 0 days 00:00:32.850000
# 7           8.0    1.0        NaT       NaT 0 days 00:00:33.037000
# 8           9.0    1.0        NaT       NaT 0 days 00:00:33.034000
# ...         ...    ...        ...       ...                    ...
# 999        35.0    3.0        NaT       NaT 0 days 00:00:32.608000
# 1000       36.0    3.0        NaT       NaT 0 days 00:00:32.772000
# 1001       37.0    3.0        NaT       NaT 0 days 00:00:32.614000
# 1002       38.0    3.0        NaT       NaT 0 days 00:00:32.626000
# 1003       39.0    3.0        NaT       NaT 0 days 00:00:32.604000
#
#                 Sector2Time  ... TrackStatus Position Deleted  \
# 4    0 days 00:00:30.260000  ...           1      1.0   False
# 5    0 days 00:00:29.969000  ...           1      1.0   False
# 6    0 days 00:00:29.847000  ...           1      1.0   False
# 7    0 days 00:00:29.899000  ...           1      1.0   False
# 8    0 days 00:00:29.860000  ...           1      1.0   False
# ...                     ...  ...         ...      ...     ...
# 999  0 days 00:00:29.978000  ...           1     18.0   False
# 1000 0 days 00:00:30.294000  ...           1     18.0   False
# 1001 0 days 00:00:30.202000  ...           1     18.0   False
# 1002 0 days 00:00:30.234000  ...           1     18.0    True
# 1003 0 days 00:00:30.890000  ...           1     17.0   False
#
#                        DeletedReason  FastF1Generated  IsAccurate  \
# 4                                               False        True
# 5                                               False        True
# 6                                               False        True
# 7                                               False        True
# 8                                               False        True
# ...                              ...              ...         ...
# 999                                             False        True
# 1000                                            False        True
# 1001                                            False        True
# 1002  TRACK LIMITS AT TURN 2 LAP 38             False        True
# 1003                                            False        True
#
#       LapTime(seconds)  Sector1Time(seconds)  Sector2Time(seconds)  \
# 4               90.273                33.310                30.260
# 5               89.409                33.139                29.969
# 6               89.083                32.850                29.847
# 7               89.362                33.037                29.899
# 8               89.326                33.034                29.860
# ...                ...                   ...                   ...
# 999             88.571                32.608                29.978
# 1000            89.054                32.772                30.294
# 1001            88.881                32.614                30.202
# 1002            88.976                32.626                30.234
# 1003            89.587                32.604                30.890
#
#      Sector3Time(seconds)
# 4                  26.703
# 5                  26.301
# 6                  26.386
# 7                  26.426
# 8                  26.432
# ...                   ...
# 999                25.985
# 1000               25.988
# 1001               26.065
# 1002               26.116
# 1003               26.093
#
# [806 rows x 35 columns]

# %%
sector_average = laps.groupby('Driver')[['Sector1Time(seconds)', 'Sector2Time(seconds)', 'Sector3Time(seconds)']].mean()
sector_average
# Out:
#         Sector1Time(seconds)  Sector2Time(seconds)  Sector3Time(seconds)
# Driver
# ALB                32.729891             29.825913             26.080370
# ALO                32.373844             29.611489             25.945600
# BOT                32.832792             29.713979             26.294917
# GAS                32.802467             29.588733             25.990333
# HUL                32.809333             29.798200             26.146333
# LAW                33.472213             30.108064             26.257638
# LEC                32.466689             29.544756             25.916111
# MAG                33.017348             30.007696             26.354739
# NOR                32.171267             29.588356             25.590689
# OCO                32.721200             29.649778             25.944000
# PER                32.686178             29.859244             25.920800
# PIA                32.055111             29.511644             25.679111
# RUS                32.441739             29.532957             25.922630
# SAR                33.050167             30.338333             26.393267
# STR                32.948729             29.879583             26.141458
# TSU                33.046244             29.837733             26.141711
# VER                32.189778             29.358422             25.734133
# ZHO                32.736111             29.843889             26.082800

# %%
fastest_per_sector = sector_average.min()
fastest_per_sector
# Out:
# Sector1Time(seconds)    32.055111
# Sector2Time(seconds)    29.358422
# Sector3Time(seconds)    25.590689
# dtype: float64

# %%
sector_gap = sector_average - fastest_per_sector
sector_gap
# Out:
#         Sector1Time(seconds)  Sector2Time(seconds)  Sector3Time(seconds)
# Driver
# ALB                 0.674780              0.467491              0.489681
# ALO                 0.318733              0.253067              0.354911
# BOT                 0.777681              0.355557              0.704228
# GAS                 0.747356              0.230311              0.399644
# HUL                 0.754222              0.439778              0.555644
# LAW                 1.417102              0.749642              0.666949
# LEC                 0.411578              0.186333              0.325422
# MAG                 0.962237              0.649273              0.764050
# NOR                 0.116156              0.229933              0.000000
# OCO                 0.666089              0.291356              0.353311
# PER                 0.631067              0.500822              0.330111
# PIA                 0.000000              0.153222              0.088422
# RUS                 0.386628              0.174534              0.331942
# SAR                 0.995056              0.979911              0.802578
# STR                 0.893618              0.521161              0.550769
# TSU                 0.991133              0.479311              0.551022
# VER                 0.134667              0.000000              0.143444
# ZHO                 0.681000              0.485467              0.492111

# %%
sector_gap.columns = ['Sector1Gap', 'Sector2Gap', 'Sector3Gap']
sector_gap
# Out:
#         Sector1Gap  Sector2Gap  Sector3Gap
# Driver
# ALB       0.674780    0.467491    0.489681
# ALO       0.318733    0.253067    0.354911
# BOT       0.777681    0.355557    0.704228
# GAS       0.747356    0.230311    0.399644
# HUL       0.754222    0.439778    0.555644
# LAW       1.417102    0.749642    0.666949
# LEC       0.411578    0.186333    0.325422
# MAG       0.962237    0.649273    0.764050
# NOR       0.116156    0.229933    0.000000
# OCO       0.666089    0.291356    0.353311
# PER       0.631067    0.500822    0.330111
# PIA       0.000000    0.153222    0.088422
# RUS       0.386628    0.174534    0.331942
# SAR       0.995056    0.979911    0.802578
# STR       0.893618    0.521161    0.550769
# TSU       0.991133    0.479311    0.551022
# VER       0.134667    0.000000    0.143444
# ZHO       0.681000    0.485467    0.492111

# %%
plt.figure(figsize = (12, 6))
sns.heatmap(
    data = sector_gap,
    annot = True,
    cmap = 'RdYlGn_r',
    fmt = '.3f'
)
plt.title('Time Lost per Sector (seconds behind fastest)')
plt.show()

# %% [markdown]
# Green = closer to the fastest driver.
#
# Red = losing time, far from the fastest driver.
